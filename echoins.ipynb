# %% [markdown]
# # fetching comments sample

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB47XVqTefMFpRGzMavn1KMc9W1Jf8BrCg"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="eBkcXERfZO0",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Hey guys, the support in this video has been unbelievable, to say the least. Thank you everyone from the bottom of my heart. Means a lot! 🙏<br><br>Also, just to clarify, I left Beebom because of a very simple reason. My ultimate dream was to have my own channel and this felt like the right time to do my own thing. <br>- Rupesh
# Is there any fitness band that works on ios?
# Bhupesh
# Isi bande ki wajah se Boltz watch kharidi thi maine ....<br><br>I repent.
# Hindi na bolne ke wajah se beebom walo ne nikaal dia 💀
# Hi, can this be used while swimming? Great video &amp; please elaborate on water / dust resistance.
# Beebom wasn’t your channel ??😮
# Yes
# we lpove you rupesh but whAT HAPPEND TO BEEBOM TO YOU
# How come it have both 5 atm and ip 68... if it is certified with 5 atm... its lot more than ip 68, then y advertising ip 68.. anyone explain
# Why there is no camera shutter button 🔘
# Unsubscribed beebom Sir
# If it&#39;s personal channel than great move
# No GPS is definitely a deal Breaker. It is not a true Fitness band if it requires you to always keep your phone with you for movement tracking. Should have launched at 1-2k higher but GPS is must.
# What happened to Beebom?
# Most of us watched Beebom because of you. You were the face of Beebom, now that you left Beebom it is not just the same. But at the same we are happy that you started a new channel. Keep going brother. ✌️
# HUAWEI HAS SAME DESIGN SELLING HERE IN SG
# What happened with Beebom?
# Hey Rupesh All the best for your new channel.<br>what happened to BeeBom?
# Sadly it won&#39;t pair with ios 😢
# Glad to see you back Rupesh with your new venture. Good luck! <br>As for the AOD flicker, yes, I am using Fit 3 currently, and it does flicker when observed closely.
# Only drawbacks : no mic , display bazzels and I will prefer rounded display...
# Guys don’t buy this watch. It doesn’t have any support for iOS. No app which can support this on iOS
# Bro this watch is released by honor 2 years ago 😊 😅waste release from Samsung
# can it be used with iOS phone?
# I came here to find you first video and wish you best of luck.
# New Chanel?
# Can it connect to Xiaomi phones? THanks
# saw rupesh and thought this channel is impersonating beebom.. was going to report this.. till I read the pinned comment 😂😂😂 instantly followed.. 😂😂
# 5000 me toh vostok, Casio ki best watches aa jayegi Jo 10 saal Kam se kam chalege
# Yeah mine flickers too, I’m guessing it’s to increase battery life by reducing refresh rate
# It&#39;s a honor band 6 stamped as Samsung
# Are you from BeeBom?
# I love the GF3... OS is so smooth to use and so comfortable! I wonder if older Galaxy watches before they jumped into bed with Google and Google WearOS where as smooth as this GF3?
# Why did he left beeboom???
# Does anyone have the problem that the steps are always reset, or the steps are taken over from the cell phone and overwrite the steps on the watch?
# No gps ?
# Thanks for being your old school style ❤
# Plz provide led tv reviews also
# killer deal
# expected for this🥰🥰
# Hey , can this be used with iphone ?
# Beebom is incomplete without your name tag line
# Bluetooth calling
# Have you left beboom?
# Dubai Price 160 DHS = 3639 ₹
# Ios compatibility?
# This includes Mike. But I don&#39;t know why
# Sillycorn has a face value of you. Good to go❤
# is this a 30hz or 60hz screen ??
# Why do i feel that samsung purchased the huawei watch fit 1 from huawei and released it under another name?
# Subscribed
# does it work on ios or older samsung devices ?
# We love Rupesh Sir 🤍
# Beebom😮
# Which smartwatch is best under 4-5k?
# 😮😮❤❤
# Display resolution is not as good as CMF Watch Pro and that gives an extra edge to CMF watch for sharper display.
# Hey Rupesh could you make a video for a good pc setup under 1 lakh to 70k , because I  fell that only you understand our price constraints and the indian markets conditions properly :)
# ❤❤❤❤
# Is this compatible with apple
# I have unsubscribed “Beebom”
# Only reason i watch beebom was because of Rupesh ❤️🤍
# Other things 😂😂😂
# Based on my experience I would say you shouldn&#39;t buy smartwatch unless u need to track ur activity <br>Spend same money in analog watch that will get more attentions........<br>As a student myself lately I realised smartwatches are toys and u will be irritated charging it
# It&#39;s just feels like Huawei band 6 with samsung logo
# Is taking calls on a smartwatch such a mainstream?
# be blessed guys, and keep going
# What happened to Beebom? I came to the comment just after listening to the new channel name....
# Was trying to find you. All the best!
# No GPS. How is it killing smartwatchs?
# Welcome back, Rupesh! 🎉
# I thought this was either a stolen video or a clickbait title, then I read the pinned comment.. lol..<br><br> NGL, the other YouTube channel doesn&#39;t feel like them anymore.. <br><br><br>Welcome back man. Missed you in videos m🤌 <br>Waiting for more content 🔥🔥<br><br>Small suggestion which you probably fixed at this point.. sfx  is a bit too loud, maybe reduce by a bit and it&#39;ll be perfect 🤌
# Bro, I have been following you (beebom) since 1 year or more now. I support your dream. If you need any help with editing, do let me know
# It’s support with ios ?
# Why is this channel, can anyone explain
# Finally back , had a great void without you in tech industry. Just happy to see u
# 🏆✨Great video, very interesting! 👍🏻 With this band, can you display the emoji correctly? Thanks in advance for your attention!
# This exactly looks like huawei band 7, anyways congrats on your new venture Rupesh.
# Good to see u back rupesh
# Is it compatible with IPhone?
# 16mb ram 💀
# Bro is it compatible with I phone what I mean is it connect with I phone
# Hi bro
# I only watch BEEBOM because of you I just got your video in recommendation. ❤
# Cmf  watch pro vs Samsung fit 3 which one is best
# Honestly, the chin is a deal breaker for me. If someone could have done it in this price range, it would be Samsung. but apart form that, great for kids.
# Does it work fine with an iPhone?
# Full support for new channel brother ❤
# Subscribed ✌🏻
# I would prefer casio F91 over this any day
# Come here just for rupesh <br>Beebom sucks now😢
# Sir , did you left beebom...?
# Looks, nice. I like the light weight and long battery life. Can someone explain what accounts and apps you need to make it work on none Samsung Android phones? Is there any diff in features compared to when using it with a Samsung Android phone and other Android phones? How about using it with an iPhone? Is all the needed software available on iPhone as well? Does it work well?
# Wtf the subsribe button glowed when you said subscribe 😮
# Whats the strap size ?
# Wait for redmi watch 4
# <a href="https://www.youtube.com/watch?v=eBkcXERfZO0&amp;t=233">3:53</a> 😂
# What happened to beebom
# mannnn i was searching for this dude 🤪 found him here, great to hear him speak

# %% [markdown]
# # creating a data frame out of it

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB47XVqTefMFpRGzMavn1KMc9W1Jf8BrCg"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="eBkcXERfZO0",
    maxResults=100
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# Out:
#                   author          published_at            updated_at
# 0       @SillycornsMedia  2024-03-02T10:15:12Z  2024-03-02T10:15:12Z  \
# 1           @Srikantbhat  2024-04-11T07:33:59Z  2024-04-11T07:33:59Z
# 2        @darkknight8582  2024-04-11T07:32:59Z  2024-04-11T07:32:59Z
# 3    @deepakSharma-we7rj  2024-04-10T17:49:57Z  2024-04-10T17:49:57Z
# 4       @user-yz2ui1fp3o  2024-04-10T13:52:06Z  2024-04-10T13:52:06Z
# 5               @rota234  2024-04-08T09:04:37Z  2024-04-08T09:04:37Z
# 6               @Ashes-9  2024-04-07T17:39:42Z  2024-04-07T17:39:50Z
# 7       @user-vt8zp9wd3w  2024-04-07T11:41:26Z  2024-04-07T11:41:26Z
# 8    @amitkumargupta8486  2024-04-06T15:41:45Z  2024-04-06T15:41:45Z
# 9  @bodalasyamsundar1467  2024-04-06T02:19:26Z  2024-04-06T02:19:26Z
#
#    like_count                                               text
# 0        1476  Hey guys, the support in this video has been u...
# 1           0       Is there any fitness band that works on ios?
# 2           0                                            Bhupesh
# 3           0  Isi bande ki wajah se Boltz watch kharidi thi ...
# 4           0  Hindi na bolne ke wajah se beebom walo ne nika...
# 5           0  Hi, can this be used while swimming? Great vid...
# 6           0                     Beebom wasn’t your channel ??😮
# 7           0                                                Yes
# 8           0  we lpove you rupesh but whAT HAPPEND TO BEEBOM...
# 9           0  How come it have both 5 atm and ip 68... if it...

# %% [markdown]
# # translating the comments to english

# %%
from googletrans import Translator
def translate_text(text):
    translator = Translator()
    translated_text = translator.translate(text)
    return translated_text.text

# Apply translation to the 'text' column
df['translated_text'] = df['text'].apply(translate_text)

# %%
df
# Out:
#                  author          published_at            updated_at
# 0      @SillycornsMedia  2024-03-02T10:15:12Z  2024-03-02T10:15:12Z  \
# 1          @Srikantbhat  2024-04-11T07:33:59Z  2024-04-11T07:33:59Z
# 2       @darkknight8582  2024-04-11T07:32:59Z  2024-04-11T07:32:59Z
# 3   @deepakSharma-we7rj  2024-04-10T17:49:57Z  2024-04-10T17:49:57Z
# 4      @user-yz2ui1fp3o  2024-04-10T13:52:06Z  2024-04-10T13:52:06Z
# ..                  ...                   ...                   ...
# 95            @Tamil_94  2024-03-14T14:34:22Z  2024-03-14T14:34:22Z
# 96       @ALLKNEWPRINCE  2024-03-14T14:15:26Z  2024-03-14T14:15:26Z
# 97      @venkatadri1299  2024-03-14T08:04:22Z  2024-03-14T08:04:22Z
# 98      @venkatadri1299  2024-03-14T08:00:53Z  2024-03-14T08:00:53Z
# 99           @aaditya-j  2024-03-14T04:05:18Z  2024-03-14T04:05:18Z
#
#     like_count                                               text
# 0         1476  Hey guys, the support in this video has been u...  \
# 1            0       Is there any fitness band that works on ios?
# 2            0                                            Bhupesh
# 3            0  Isi bande ki wajah se Boltz watch kharidi thi ...
# 4            0  Hindi na bolne ke wajah se beebom walo ne nika...
# ..         ...                                                ...
# 95           0                             Whats the strap size ?
# 96           0                             Wait for redmi watch 4
# 97           0  <a href="https://www.youtube.com/watch?v=eBkcX...
# 98           0                            What happened to beebom
# 99           0  mannnn i was searching for this dude 🤪 found h...
#
#                                       translated_text
# 0   Hey guys, the support in this video has been u...
# 1        Is there any fitness band that works on ios?
# 2                                             Bhupesh
# 3   Because of this bandh, I bought Boltz Watch .....
# 4   Hindi Na Bolne Ke Wajah Se Beebom Walo Ne Nika...
# ..                                                ...
# 95                             Whats the strap size ?
# 96                             Wait for redmi watch 4
# 97  <a href="https://www.youtube.com/watch?v=eBkcX...
# 98                            What happened to beebom
# 99  mannnn i was searching for this dude 🤪 found h...
#
# [100 rows x 6 columns]

# %% [markdown]
# # sentiment using VADER

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Function to perform sentiment analysis using VADER
def get_vader_sentiment(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(text)
    # We extract the compound score which represents the overall sentiment
    return sentiment_score['compound']

# Apply sentiment analysis to the 'translated_text' column
df['vader_sentiment'] = df['translated_text'].apply(get_vader_sentiment)

# %%
df
# Out:
#                  author          published_at            updated_at
# 0      @SillycornsMedia  2024-03-02T10:15:12Z  2024-03-02T10:15:12Z  \
# 1          @Srikantbhat  2024-04-11T07:33:59Z  2024-04-11T07:33:59Z
# 2       @darkknight8582  2024-04-11T07:32:59Z  2024-04-11T07:32:59Z
# 3   @deepakSharma-we7rj  2024-04-10T17:49:57Z  2024-04-10T17:49:57Z
# 4      @user-yz2ui1fp3o  2024-04-10T13:52:06Z  2024-04-10T13:52:06Z
# ..                  ...                   ...                   ...
# 95            @Tamil_94  2024-03-14T14:34:22Z  2024-03-14T14:34:22Z
# 96       @ALLKNEWPRINCE  2024-03-14T14:15:26Z  2024-03-14T14:15:26Z
# 97      @venkatadri1299  2024-03-14T08:04:22Z  2024-03-14T08:04:22Z
# 98      @venkatadri1299  2024-03-14T08:00:53Z  2024-03-14T08:00:53Z
# 99           @aaditya-j  2024-03-14T04:05:18Z  2024-03-14T04:05:18Z
#
#     like_count                                               text
# 0         1476  Hey guys, the support in this video has been u...  \
# 1            0       Is there any fitness band that works on ios?
# 2            0                                            Bhupesh
# 3            0  Isi bande ki wajah se Boltz watch kharidi thi ...
# 4            0  Hindi na bolne ke wajah se beebom walo ne nika...
# ..         ...                                                ...
# 95           0                             Whats the strap size ?
# 96           0                             Wait for redmi watch 4
# 97           0  <a href="https://www.youtube.com/watch?v=eBkcX...
# 98           0                            What happened to beebom
# 99           0  mannnn i was searching for this dude 🤪 found h...
#
#                                       translated_text  vader_sentiment
# 0   Hey guys, the support in this video has been u...           0.8855
# 1        Is there any fitness band that works on ios?           0.2732
# 2                                             Bhupesh           0.0000
# 3   Because of this bandh, I bought Boltz Watch .....           0.0000
# 4   Hindi Na Bolne Ke Wajah Se Beebom Walo Ne Nika...           0.0000
# ..                                                ...              ...
# 95                             Whats the strap size ?           0.0000
# 96                             Wait for redmi watch 4           0.0000
# 97  <a href="https://www.youtube.com/watch?v=eBkcX...           0.4404
# 98                            What happened to beebom           0.0000
# 99  mannnn i was searching for this dude 🤪 found h...           0.6249
#
# [100 rows x 7 columns]

# %% [markdown]
# # streamlit app

# %%
# df.to_csv(f'{videoId}.csv', index=False)
df.to_csv('1.csv', index=False)
